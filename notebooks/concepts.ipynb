# %% [markdown]
# # The Five Steps of LangGraph:
# 1. Define the State class
# 2. Start the graph builder
# 3. Create Nodes
# 4. Create Edges
# 5. Compile the graph
#
# -> Then you can call graph.invoke(state)
